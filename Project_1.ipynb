# %% [markdown]
# <a href="https://colab.research.google.com/github/aKrish23-luffy/Project/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
categorial_cols = df.select_dtypes(include=['object']).columns
for col in categorial_cols:
  df[col] = df[col].fillna(df[col].mode()[0])

# %%
original_count = len(df)
df = df.drop_duplicates()
removed_dupes = original_count - len(df)

if removed_dupes > 0:
  print(f"Cleaned up {removed_dupes} identical rows. Data is now unique")
else:
  print("Looked for duplicates, but data was already unique! ")
# Out:
# Looked for duplicates, but data was already unique!

# %%
for col in ['Age', 'Fare']:
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1

  lower_limit = Q1 - 5.5 * IQR
  upper_limit = Q3 + 1.5 * IQR

  df = df[(df[col] >= lower_limit) & (df[col] <= upper_limit)]

  print(" Extreme outliers have been trimmed for a smoother model")
# Out:
#  Extreme outliers have been trimmed for a smoother model
#  Extreme outliers have been trimmed for a smoother model

# %%
useless_info = ['PassengerId', 'Name', 'Ticket', 'Cabin']
df_final = df.drop(columns=useless_info)

# %%
df_final.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S
# 5         0       3    male  28.0      0      0   8.4583        Q
